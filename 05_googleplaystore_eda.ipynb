# %% [markdown]
# # Google App Store EDA

# %% [markdown]
# Name: Hashir Bhatti\
# Email: bhattihashir26@gmail.com

# %%
# Import the libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import ydata_profiling as yd

# %%
df = pd.read_csv("./data/googleplaystore.csv")
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
df.shape
# Out:
# (10841, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  int64
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10841 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10839 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 1.1+ MB

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             1
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               1
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %%
df.describe()
# Out:
#             Rating       Reviews
# count  9367.000000  1.084100e+04
# mean      4.191513  4.441119e+05
# std       0.515735  2.927629e+06
# min       1.000000  0.000000e+00
# 25%       4.000000  3.800000e+01
# 50%       4.300000  2.094000e+03
# 75%       4.500000  5.476800e+04
# max       5.000000  7.815831e+07

# %%
# # Create a ProfileReport without specifying a configuration file
# profile = yd.ProfileReport(df)

# # Generate the report and save it to an HTML file
# profile.to_file("outputs/ydata_googleplaystore.html")

# %%
df.sample(10)
# Out:
#                                                    App             Category  \
# 4789                 X Home Bar - Home Bar Gesture Pro                TOOLS
# 6244                                    B y H Niños ES  BOOKS_AND_REFERENCE
# 6797                                       BT Panorama              FINANCE
# 3251   Samsung Max - Data Savings & Privacy Protection                TOOLS
# 917                                               Nick        ENTERTAINMENT
# 7849                        Grenade Practice for CS:GO               FAMILY
# 5875                                     A-Z App Store         PRODUCTIVITY
# 5208                                        ai.Bot Box         PRODUCTIVITY
# 6373                                                VK               SOCIAL
# 10322                   FE Civil Engineering Exam Prep               FAMILY
#
#        Rating  Reviews                Size      Installs  Type  Price  \
# 4789      4.0       88                2.0M       10,000+  Paid  $1.99
# 6244      4.6       53                 16M        5,000+  Free      0
# 6797      4.3       34  Varies with device        5,000+  Free      0
# 3251      4.3   330468  Varies with device   10,000,000+  Free      0
# 917       4.2   123279                 25M   10,000,000+  Free      0
# 7849      4.4      431                 17M       10,000+  Free      0
# 5875      3.2     2728                4.4M      500,000+  Free      0
# 5208      NaN        0  Varies with device       10,000+  Free      0
# 6373      3.8  5793284  Varies with device  100,000,000+  Free      0
# 10322     2.8        9                 21M        1,000+  Free      0
#
#       Content Rating                       Genres        Last Updated  \
# 4789        Everyone                        Tools        July 2, 2018
# 6244        Everyone            Books & Reference  September 22, 2015
# 6797        Everyone                      Finance       June 14, 2017
# 3251        Everyone                        Tools        May 29, 2018
# 917     Everyone 10+  Entertainment;Music & Video    January 24, 2018
# 7849        Everyone                Entertainment       June 13, 2016
# 5875        Everyone                 Productivity     October 5, 2016
# 5208        Everyone                 Productivity       March 1, 2017
# 6373      Mature 17+                       Social      August 3, 2018
# 10322       Everyone                    Education       July 27, 2018
#
#               Current Ver         Android Ver
# 4789                  1.5          4.3 and up
# 6244                1.0.2          2.3 and up
# 6797   Varies with device  Varies with device
# 3251   Varies with device  Varies with device
# 917                 2.0.8          4.4 and up
# 7849                1.1.1          4.0 and up
# 5875                1.0.5          4.1 and up
# 5208   Varies with device  Varies with device
# 6373   Varies with device  Varies with device
# 10322           5.33.3669          5.0 and up

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %% [markdown]
# ## Convert Variables to Numeric Data Type
#
# There are some variables that should be of the numeric data type, but here in this dataset they are of the object data type. We'll have to convert them to numeric. Those variables are:
#
# 1. Size
# 2. Installs
# 3. Price

# %% [markdown]
# ### 1. `Size`

# %%
# View the data type of the Size column
df['Size'].dtype
# Out:
# dtype('O')

# %%
# Number of unique values in the Size column
df['Size'].nunique()
# Out:
# 461

# %%
# Top 10 most-appearing values in the Size column
df['Size'].value_counts().sort_values(ascending=False).head(10)
# Out:
# Size
# Varies with device    1695
# 11M                    198
# 12M                    196
# 14M                    194
# 13M                    191
# 15M                    184
# 17M                    160
# 19M                    154
# 26M                    149
# 16M                    149
# Name: count, dtype: int64

# %%
# Replace 'Varies with device' with null values
df['Size'] = df['Size'].replace('Varies with device', np.nan)

# %%
# To check whether it has been replaced successfully
df['Size'].value_counts(dropna=False).sort_values(ascending=False).head(10)
# Out:
# Size
# NaN    1695
# 11M     198
# 12M     196
# 14M     194
# 13M     191
# 15M     184
# 17M     160
# 19M     154
# 26M     149
# 16M     149
# Name: count, dtype: int64

# %%
# Unique values in the Size column
df['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', nan, '9.4M', '15M', '10M', '1.2M', '26M',
#        '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k', '3.6M', '5.7M',
#        '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M', '8.9M', '3.9M',
#        '2.9M', '38M', '32M', '5.4M', '18M', '1.1M', '2.2M', '4.5M',
#        '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M', '7.1M', '3.7M',
#        '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M', '4.9M', '9.5M',
#        '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M', '4.0M', '2.3M',
#        '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M', '23k', '6.5M',
#        '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M', '8.3M', '4.3M',
#        '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M', '5.1M', '61M',
#        '66M', '79k', '8.4M', '118k', '44M', '695k', '1.6M', '6.2M', '18k',
#        '53M', '1.4M', '3.0M', '5.8M', '3.8M', '9.6M', '45M', '63M', '49M',
#        '77M', '4.4M', '4.8M', '70M', '6.9M', '9.3M', '10.0M', '8.1M',
#        '36M', '84M', '97M', '2.0M', '1.9M', '1.8M', '5.3M', '47M', '556k',
#        '526k', '76M', '7.6M', '59M', '9.7M', '78M', '72M', '43M', '7.7M',
#        '6.3M', '334k', '34M', '93M', '65M', '79M', '100M', '58M', '50M',
#        '68M', '64M', '67M', '60M', '94M', '232k', '99M', '624k', '95M',
#        '8.5k', '41k', '292k', '11k', '80M', '1.7M', '74M', '62M', '69M',
#        '75M', '98M', '85M', '82M', '96M', '87M', '71M', '86M', '91M',
#        '81M', '92M', '83M', '88M', '704k', '862k', '899k', '378k', '266k',
#        '375k', '1.3M', '975k', '980k', '4.1M', '89M', '696k', '544k',
#        '525k', '920k', '779k', '853k', '720k', '713k', '772k', '318k',
#        '58k', '241k', '196k', '857k', '51k', '953k', '865k', '251k',
#        '930k', '540k', '313k', '746k', '203k', '26k', '314k', '239k',
#        '371k', '220k', '730k', '756k', '91k', '293k', '17k', '74k', '14k',
#        '317k', '78k', '924k', '902k', '818k', '81k', '939k', '169k',
#        '45k', '475k', '965k', '90M', '545k', '61k', '283k', '655k',
#        '714k', '93k', '872k', '121k', '322k', '1.0M', '976k', '172k',
#        '238k', '549k', '206k', '954k', '444k', '717k', '210k', '609k',
#        '308k', '705k', '306k', '904k', '473k', '175k', '350k', '383k',
#        '454k', '421k', '70k', '812k', '442k', '842k', '417k', '412k',
#        '459k', '478k', '335k', '782k', '721k', '430k', '429k', '192k',
#        '200k', '460k', '728k', '496k', '816k', '414k', '506k', '887k',
#        '613k', '243k', '569k', '778k', '683k', '592k', '319k', '186k',
#        '840k', '647k', '191k', '373k', '437k', '598k', '716k', '585k',
#        '982k', '222k', '219k', '55k', '948k', '323k', '691k', '511k',
#        '951k', '963k', '25k', '554k', '351k', '27k', '82k', '208k',
#        '913k', '514k', '551k', '29k', '103k', '898k', '743k', '116k',
#        '153k', '209k', '353k', '499k', '173k', '597k', '809k', '122k',
#        '411k', '400k', '801k', '787k', '237k', '50k', '643k', '986k',
#        '97k', '516k', '837k', '780k', '961k', '269k', '20k', '498k',
#        '600k', '749k', '642k', '881k', '72k', '656k', '601k', '221k',
#        '228k', '108k', '940k', '176k', '33k', '663k', '34k', '942k',
#        '259k', '164k', '458k', '245k', '629k', '28k', '288k', '775k',
#        '785k', '636k', '916k', '994k', '309k', '485k', '914k', '903k',
#        '608k', '500k', '54k', '562k', '847k', '957k', '688k', '811k',
#        '270k', '48k', '329k', '523k', '921k', '874k', '981k', '784k',
#        '280k', '24k', '518k', '754k', '892k', '154k', '860k', '364k',
#        '387k', '626k', '161k', '879k', '39k', '970k', '170k', '141k',
#        '160k', '144k', '143k', '190k', '376k', '193k', '246k', '73k',
#        '658k', '992k', '253k', '420k', '404k', '470k', '226k', '240k',
#        '89k', '234k', '257k', '861k', '467k', '157k', '44k', '676k',
#        '67k', '552k', '885k', '1020k', '582k', '619k'], dtype=object)

# %%
# Check the data types in the 'Size' column
size_data_types = df['Size'].apply(type).unique()
print(size_data_types)
# Out:
# [<class 'str'> <class 'float'>]

# %% [markdown]
# The `Size` column now has two data types because NaN values are considered a flaot data type.

# %% [markdown]
# The logic I have applied here is that I've first converted values in kbs to mbs. Then I converted them to a float data type and created a new column named `Size (Mb)`.

# %%
# Define a function to convert sizes from kb to mb
def kb_to_mb(size):
    if size is None or pd.isna(size):
        return None
    if 'k' in size:
        return float(size.replace('k', '')) / 1024
    if 'M' in size:
        return float(size.replace('M', ''))

# %% [markdown]
# It's always better to make a copy of the original DataFrame before making any changes to it.

# %%
# Make a copy of the df
cleaned_df = df.copy()

# %%
# Apply the conversion function to the 'Size' column
cleaned_df['Size (Mb)'] = cleaned_df['Size'].apply(kb_to_mb)

# %%
cleaned_df.sample(20)
# Out:
#                                                      App             Category  \
# 9602                                Connect'Em Halloween               FAMILY
# 10509                     PIP Selfie Camera Photo Editor          PHOTOGRAPHY
# 7429                               Miami Crime Vice Town                 GAME
# 8339                       DF Wall Plus – Droid Firewall                TOOLS
# 6021                                           BD TYCOON               FAMILY
# 3574                                         Cloud Print         PRODUCTIVITY
# 8393                                          DG Monitor             BUSINESS
# 4636                                              /u/app        COMMUNICATION
# 5929            Arabic Alphabet Alif Ba Ta Wooden Blocks               FAMILY
# 2368                                          live Point              MEDICAL
# 4376                        m.ride - your motorcycle app    AUTO_AND_VEHICLES
# 6025                                     BD CRICKET LIVE               SPORTS
# 10825                                 Naruto & Boruto FR               SOCIAL
# 5353                                  Amazon for Tablets             SHOPPING
# 8655   Notes : Colorful Notepad Note,To Do,Reminder,Memo            LIFESTYLE
# 10791                                  Winter Wonderland                 GAME
# 1146    Moneycontrol – Stocks, Sensex, Mutual Funds, IPO              FINANCE
# 6693                                    Táxi Nacional BR  MAPS_AND_NAVIGATION
# 7427                                      CJ DVD Rentals        COMMUNICATION
# 3019                                          MLB At Bat               SPORTS
#
#        Rating  Reviews  Size      Installs  Type Price Content Rating  \
# 9602      4.5     6673  4.4M      500,000+  Free     0       Everyone
# 10509     4.4   156322   NaN   10,000,000+  Free     0       Everyone
# 7429      4.1   154519   99M   10,000,000+  Free     0     Mature 17+
# 8339      NaN        9  6.3M          500+  Free     0       Everyone
# 6021      3.3       16   33M          500+  Free     0       Everyone
# 3574      4.1   282460   NaN  500,000,000+  Free     0       Everyone
# 8393      NaN        1  4.5M          100+  Free     0       Everyone
# 4636      4.7      573   53M       10,000+  Free     0     Mature 17+
# 5929      4.6       66   17M       10,000+  Free     0       Everyone
# 2368      3.6       54   17M        5,000+  Free     0     Mature 17+
# 4376      4.5      189   16M       10,000+  Free     0       Everyone
# 6025      4.6     1238  9.5M      100,000+  Free     0       Everyone
# 10825     NaN        7  7.7M          100+  Free     0           Teen
# 5353      4.0   141584   22M   10,000,000+  Free     0           Teen
# 8655      4.6    10484  9.0M    1,000,000+  Free     0       Everyone
# 10791     4.0     1287   38M       50,000+  Free     0       Everyone
# 1146      4.4   281485   NaN    5,000,000+  Free     0       Everyone
# 6693      NaN       88  9.1M        5,000+  Free     0       Everyone
# 7427      1.0        5   13M          100+  Free     0       Everyone
# 3019      4.2    82882   NaN    5,000,000+  Free     0       Everyone
#
#                       Genres        Last Updated         Current Ver  \
# 9602                  Puzzle  September 23, 2016               1.0.7
# 10509            Photography    February 1, 2018  Varies with device
# 7429                  Action         May 9, 2017                 1.4
# 8339                   Tools     August 20, 2017                 1.0
# 6021              Simulation        July 6, 2017                 1.2
# 3574            Productivity        May 23, 2018  Varies with device
# 8393                Business    October 12, 2017            1.0.0.17
# 4636           Communication        July 3, 2018               4.2.4
# 5929   Educational;Education   February 25, 2018               1.0.0
# 2368                 Medical        July 3, 2018               2.6.5
# 4376         Auto & Vehicles        July 3, 2018               1.1.6
# 6025                  Sports    January 15, 2018                 3.0
# 10825                 Social    February 2, 2018                 1.0
# 5353                Shopping       July 31, 2018         16.14.0.850
# 8655               Lifestyle        June 9, 2018               1.4.9
# 10791                   Word   December 18, 2013                 1.0
# 1146                 Finance        May 11, 2018  Varies with device
# 6693       Maps & Navigation      August 2, 2018              3.46.5
# 7427           Communication     October 6, 2017                 1.0
# 3019                  Sports       July 30, 2018  Varies with device
#
#               Android Ver  Size (Mb)
# 9602           2.0 and up        4.4
# 10509  Varies with device        NaN
# 7429           2.3 and up       99.0
# 8339         4.0.3 and up        6.3
# 6021           4.1 and up       33.0
# 3574   Varies with device        NaN
# 8393           4.0 and up        4.5
# 4636           4.1 and up       53.0
# 5929           2.3 and up       17.0
# 2368           4.1 and up       17.0
# 4376           6.0 and up       16.0
# 6025         4.0.3 and up        9.5
# 10825          4.0 and up        7.7
# 5353           4.4 and up       22.0
# 8655           4.1 and up        9.0
# 10791          2.2 and up       38.0
# 1146   Varies with device        NaN
# 6693         4.0.3 and up        9.1
# 7427           4.1 and up       13.0
# 3019   Varies with device        NaN

# %%
# Drop the `Size` column
cleaned_df.drop('Size', axis=1, inplace=True)

# %% [markdown]
# ### 2. `Installs`

# %%
# Check the data types in the 'Installs' column
installs_data_types = cleaned_df['Installs'].apply(type).unique()
print(installs_data_types)
# Out:
# [<class 'str'>]

# %%
# Define a function to convert the 'Installs' values to numeric
def convert_installs(installs):
    if isinstance(installs, str):
        return int(installs.replace(',', '').replace('+', ''))
    else:
        return installs
    
# Apply the conversion function to the 'Installs' column
cleaned_df['Installs'] = cleaned_df['Installs'].apply(convert_installs)

# %%
cleaned_df['Installs']
# Out:
# 0           10000
# 1          500000
# 2         5000000
# 3        50000000
# 4          100000
#            ...
# 10836        5000
# 10837         100
# 10838        1000
# 10839        1000
# 10840    10000000
# Name: Installs, Length: 10841, dtype: int64

# %%
cleaned_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Installs  Type Price Content Rating                     Genres  \
# 0      159     10000  Free     0       Everyone               Art & Design
# 1      967    500000  Free     0       Everyone  Art & Design;Pretend Play
# 2    87510   5000000  Free     0       Everyone               Art & Design
# 3   215644  50000000  Free     0           Teen               Art & Design
# 4      967    100000  Free     0       Everyone    Art & Design;Creativity
#
#        Last Updated         Current Ver   Android Ver  Size (Mb)
# 0   January 7, 2018               1.0.0  4.0.3 and up       19.0
# 1  January 15, 2018               2.0.0  4.0.3 and up       14.0
# 2    August 1, 2018               1.2.4  4.0.3 and up        8.7
# 3      June 8, 2018  Varies with device    4.2 and up       25.0
# 4     June 20, 2018                 1.1    4.4 and up        2.8

# %%
# Check it has been successfully converted on numerical variable
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  int64
#  4   Installs        10841 non-null  int64
#  5   Type            10840 non-null  object
#  6   Price           10841 non-null  object
#  7   Content Rating  10841 non-null  object
#  8   Genres          10840 non-null  object
#  9   Last Updated    10841 non-null  object
#  10  Current Ver     10833 non-null  object
#  11  Android Ver     10839 non-null  object
#  12  Size (Mb)       9146 non-null   float64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 1.1+ MB

# %% [markdown]
# ### 3. `Price`

# %%
# Check the data types in the 'Price' column
price_data_types = cleaned_df['Price'].apply(type).unique()
print(price_data_types)
# Out:
# [<class 'str'>]

# %%
cleaned_df['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
#        '$394.99', '$1.26', '$1.20', '$1.04'], dtype=object)

# %%
# Define a function to convert the 'Price' values to float
def convert_price(price):
    if isinstance(price, str) and price.startswith('$'):
        return float(price.replace('$', ''))
    else:
        return None
    
# Apply the conversion function to the 'Price' column
cleaned_df['Price ($)'] = cleaned_df['Price'].apply(convert_price)

# %%
cleaned_df['Price ($)'].unique()
# Out:
# array([   nan,   4.99,   3.99,   6.99,   1.49,   2.99,   7.99,   5.99,
#          3.49,   1.99,   9.99,   7.49,   0.99,   9.  ,   5.49,  10.  ,
#         24.99,  11.99,  79.99,  16.99,  14.99,   1.  ,  29.99,  12.99,
#          2.49,  10.99,   1.5 ,  19.99,  15.99,  33.99,  74.99,  39.99,
#          3.95,   4.49,   1.7 ,   8.99,   2.  ,   3.88,  25.99, 399.99,
#         17.99, 400.  ,   3.02,   1.76,   4.84,   4.77,   1.61,   2.5 ,
#          1.59,   6.49,   1.29,   5.  ,  13.99, 299.99, 379.99,  37.99,
#         18.99, 389.99,  19.9 ,   8.49,   1.75,  14.  ,   4.85,  46.99,
#        109.99, 154.99,   3.08,   2.59,   4.8 ,   1.96,  19.4 ,   3.9 ,
#          4.59,  15.46,   3.04,   4.29,   2.6 ,   3.28,   4.6 ,  28.99,
#          2.95,   2.9 ,   1.97, 200.  ,  89.99,   2.56,  30.99,   3.61,
#        394.99,   1.26,   1.2 ,   1.04])

# %%
# Drop the Price column
cleaned_df.drop("Price", axis=1, inplace=True)

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  int64
#  4   Installs        10841 non-null  int64
#  5   Type            10840 non-null  object
#  6   Content Rating  10841 non-null  object
#  7   Genres          10840 non-null  object
#  8   Last Updated    10841 non-null  object
#  9   Current Ver     10833 non-null  object
#  10  Android Ver     10839 non-null  object
#  11  Size (Mb)       9146 non-null   float64
#  12  Price ($)       800 non-null    float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1.1+ MB

# %%
cleaned_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Installs  Type Content Rating                     Genres  \
# 0      159     10000  Free       Everyone               Art & Design
# 1      967    500000  Free       Everyone  Art & Design;Pretend Play
# 2    87510   5000000  Free       Everyone               Art & Design
# 3   215644  50000000  Free           Teen               Art & Design
# 4      967    100000  Free       Everyone    Art & Design;Creativity
#
#        Last Updated         Current Ver   Android Ver  Size (Mb)  Price ($)
# 0   January 7, 2018               1.0.0  4.0.3 and up       19.0        NaN
# 1  January 15, 2018               2.0.0  4.0.3 and up       14.0        NaN
# 2    August 1, 2018               1.2.4  4.0.3 and up        8.7        NaN
# 3      June 8, 2018  Varies with device    4.2 and up       25.0        NaN
# 4     June 20, 2018                 1.1    4.4 and up        2.8        NaN

# %%
cleaned_df.to_csv("cleaned_googleplaystore.csv")
